# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import joblib

# %%
#https://en.wikipedia.org/wiki/Levenberg–Marquardt_algorithm
#Levenberg–Marquardt algorithm

# %%
data_path = "../data/chicago_data.csv"
data_file = pd.read_csv(data_path)

regulation = 10000 #prevent overfitting
data_file = data_file[:regulation]

data_file.dropna(axis=0, inplace=True)
data_file.drop_duplicates(inplace=True)
data_file.drop(columns=['ID', 'Case Number'], inplace=True)

# %%
# Feature extraction
data_file["Date"] = pd.to_datetime(data_file["Date"])
data_file["DayOfTheWeek"] = data_file["Date"].dt.dayofweek
data_file['Month'] = data_file['Date'].dt.month
data_file['Day'] = data_file['Date'].dt.day  
data_file['Hour'] = data_file['Date'].dt.hour  
data_file.drop(columns=['Date'], inplace=True)  
data_file.head()
# Out:
#                   Block  IUCR Primary Type                    Description  \
# 11  035XX S INDIANA AVE  0820        THEFT                 $500 AND UNDER
# 12      005XX W 32ND ST  0460      BATTERY                         SIMPLE
# 13    081XX S COLES AVE  051A      ASSAULT           AGGRAVATED - HANDGUN
# 14  065XX S WOLCOTT AVE  0460      BATTERY                         SIMPLE
# 15  062XX S ABERDEEN ST  0430      BATTERY  AGGRAVATED: OTHER DANG WEAPON
#
#            Location Description  Arrest  Domestic  Beat  District  Ward  ...  \
# 11                    APARTMENT   False     False   212       2.0   3.0  ...
# 12                    APARTMENT    True     False   915       9.0  11.0  ...
# 13                       STREET    True     False   422       4.0   7.0  ...
# 14  RESIDENCE - PORCH / HALLWAY   False     False   726       7.0  15.0  ...
# 15                       STREET   False     False   712       7.0  16.0  ...
#
#     Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 11     1881621.0  2020  05/14/2020 08:47:15 AM  41.830482 -87.621752
# 12     1883705.0  2020  04/23/2020 03:45:11 PM  41.836310 -87.639624
# 13     1851595.0  2020  07/08/2020 03:41:45 PM  41.747610 -87.549179
# 14     1861251.0  2020  10/04/2020 03:43:55 PM  41.774878 -87.671375
# 15     1863524.0  2005  02/28/2018 03:56:25 PM  41.781003 -87.652107
#
#                          Location  DayOfTheWeek  Month Day  Hour
# 11  (41.830481843, -87.621751752)             3      5   7    10
# 12  (41.836310224, -87.639624112)             3      4  16     5
# 13  (41.747609555, -87.549179329)             2      7   1    10
# 14   (41.77487752, -87.671374872)             6      9  27    23
# 15  (41.781002663, -87.652107119)             6      7  10    15
#
# [5 rows x 23 columns]

# %%
features = ["DayOfTheWeek", "Month", "Hour", "Year"]
targets = ["Location Description", "Description", "Primary Type", "Arrest"]

label_encoders = {}
pca_encoders = {}

for col in targets:
    label_encoders[col] = LabelEncoder()
    data_file[col] = label_encoders[col].fit_transform(data_file[col])

# %%
X = data_file[features]
Y = data_file[targets]

# %%
joblib.dump(label_encoders, "../models/label_encoders.pickle")
# Out:
# ['../models/label_encoders.pickle']

# %%
X_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=42, test_size=0.3)

# %%
print("Shapes of training data:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("\nShapes of testing data:")
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# Shapes of training data:
# X_train: (6274, 4)
# y_train: (6274, 4)
#
# Shapes of testing data:
# x_test: (2690, 4)
# y_test: (2690, 4)

# %% [markdown]
# # SVM BELOW

# %%
from sklearn.svm import SVC
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'estimator__C': [0.1, 1, 10, 100, 1000], 'estimator__gamma': ['scale', 'auto'], "estimator_kernal": ["rbf", "linear", "poly", "precomputed"]}
grid_search = GridSearchCV(estimator=MultiOutputClassifier(SVC(kernel='rbf')), param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=MultiOutputClassifier(estimator=SVC()),
#              param_grid={'estimator__C': [0.1, 1, 10, 100, 1000],
#                          'estimator__gamma': ['scale', 'auto']})

# %%
best_params = grid_search.best_params_
best_svm_model = MultiOutputClassifier(SVC(kernel='rbf', C=best_params['estimator__C'], gamma=best_params['estimator__gamma']))
best_svm_model.fit(X_train, y_train)
# Out:
# MultiOutputClassifier(estimator=SVC(C=1000, gamma='auto'))

# %%
joblib.dump(best_svm_model, "../models/typeLocation.pickle")
# Out:
# ['../models/typeLocation.pickle']

# %%
predictions = best_svm_model.predict(x_test)  

print(predictions[:50])
print("\n",y_test[:50])
# Out:
# [[103  40   2   0]
#  [106  75  16   0]
#  [ 14 227   6   0]
#  [ 14 203  25   0]
#  [ 14 117  17   0]
#  [106 203   2   0]
#  [ 88 203  25   0]
#  [ 88 100   2   0]
#  [106 160  25   0]
#  [106 203   2   0]
#  [ 14 100   2   0]
#  [106 232   6   0]
#  [ 14 203   2   0]
#  [ 14 100   2   0]
#  [106 115  25   0]
#  [106 187  19   1]
#  [106 232  25   0]
#  [106 203  25   0]
#  [ 14   0  25   0]
#  [ 14 119  25   0]
#  [ 88 115   6   0]
#  [ 12 232   6   0]
#  [ 14 203   6   0]
#  [ 14 100   9   0]
#  [106   0  25   0]
#  [106 160  25   0]
#  [ 14  20  25   0]
#  [103  38   2   0]
#  [ 21 110  17   1]
#  [106 227   6   0]
#  [ 40 203   2   0]
#  [ 90   8   1   0]
#  [ 53 195  17   1]
#  [106   8   2   0]
#  [106 203   1   0]
#  [ 51 195  25   0]
#  [ 38   0  25   0]
#  [106 100   2   0]
#  [106 232   6   0]
#  [106 167  17   1]
#  [106 232   6   0]
#  [ 14 115   2   0]
#  [106 203   2   0]
#  [ 14 227   6   0]
#  [ 88 100   2   0]
#  [106 232  25   0]
#  [ 14 203  25   0]
#  [ 14  13   9   0]
#  [103 203   2   0]
#  [106   0  25   0]]
#
#        Location Description  Description  Primary Type  Arrest
# 9966                    93           68             3       0
# 6855                    88          228             8       0
# 3660                   103           46            22       0
# 5884                   106          160            25       0
# 8008                    29          251            19       0
# 4743                    88           13             2       0
# 1216                    83          160            25       0
# 2749                    86          225             6       0
# 6296                   106            8             1       0
# 6473                   106          240            26       1
# 1114                    95           78             0       0
# 335                     12          203             1       0
# 6106                   106           75            16       0
# 6408                   106           75            16       0
# 7907                   103          203             1       0
# 9257                    31          115             3       0
# 6876                   106          160            25       0
# 8694                    51            0            25       0
# 5294                   104          195            25       0
# 4213                   106          175            17       1
# 9634                    88            0            25       0
# 3433                    14          113             9       0
# 213                     90          227             6       0
# 4998                   103           46            22       0
# 7246                    14          199            19       0
# 6250                   106          160            25       0
# 2445                   106          160            25       0
# 8315                   103          227             6       0
# 9792                   101          164            17       1
# 2975                    95          118             9       0
# 2704                    88          100             2       0
# 2508                    88          232             6       0
# 2858                    14            0            25       0
# 2225                    62          195            25       0
# 3866                   106          182            17       1
# 2782                   106            0            25       0
# 2472                   106          232             6       0
# 6112                    12          232             6       0
# 4119                   106          193            26       0
# 8005                    88          227             6       0
# 3111                    14          124            19       0
# 5984                    14          115             3       0
# 5444                    12           75            16       0
# 1146                   104          195            25       0
# 9753                   106          160            25       0
# 6980                   106           75            16       0
# 6245                    83           97            16       0
# 4659                    14          115             3       0
# 5243                   106          160            25       0
# 7662                   106           97            16       0

# %%
# individual_accuracy = [predictions[col, row] == y_test.to_numpy()[col, row] for col in tqdm(range(predictions.shape[0]), desc="Doing Individual Prediction: ") for row in range(predictions.shape[1])]

# %%
#axis_accuracy = [np.array_equal(y_test.to_numpy()[:, index], predictions[:, index]) for index in tqdm(range(predictions.shape[1]), desc="Doing Axis Prediction:")]

# %%
# individual_counter = sum(1 for value in individual_accuracy if value == True)
#axis_counter = sum(1 for value in axis_accuracy if value == True)

# %%
# print("Indivudal Accuracy: ", individual_counter / len(individual_accuracy)) 
# print("Axis Accuracy: ", axis_counter / len(axis_accuracy))
# print(predictions)
# print(y_test)
